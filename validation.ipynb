# %%
from sge import StructuredGrammarEvolution
import numpy as np
from copy import deepcopy
from pandas import read_csv
from multiprocessing import Pool, Lock
from json import dumps, dump

# %%
def train(params, X, Y):
    model = StructuredGrammarEvolution(array_len=len(X[0]), **params)
    history = model.fit(X, Y)
    return {"model": model, "history":history}

# %%
def evaluate(train_file, test_file, target_column, params, n_iter):
    with open(train_file) as file:
        df_train = read_csv(file)
    X_train = df_train.drop([target_column], axis=1).values
    Y_train = df_train[target_column]

    with open(test_file) as file:
        df_test = read_csv(file)
    X_test = df_test.drop([target_column], axis=1).values
    Y_test = df_test[target_column]

    max_fitness = 0
    avg_fitness = 0
    total_fitness = 0
    fitnesses = []
    best_history = None
    for it in range(n_iter):
        train_result = train(params, X_train, Y_train)
        fitness = train_result["model"](X_test, Y_test)
        total_fitness += fitness
        fitnesses += [fitness]
        if fitness > max_fitness:
            best_history = train_result["history"]
        max_fitness = max(fitness, max_fitness)
        avg_fitness = total_fitness / (it + 1)
    fitnesses = np.array(fitnesses)

    return {
        "max": max_fitness,
        "avg": avg_fitness,
        "std": fitnesses.std(),
        "best_history": best_history
    }

# %%
def recursiveGridSearchCV(params_full,
                        index_of_param=0,  
                        params_current={},
                        index_of_choice=0):
    keys = sorted(list(params_full.keys()))

    if index_of_param == len(keys) - 1:
        yield {**params_current, keys[index_of_param]: params_full[keys[index_of_param]][index_of_choice]}
    else:
        params_current[keys[index_of_param]] = params_full[keys[index_of_param]][index_of_choice]
        ret = []
        for i in range(len(params_full[keys[index_of_param + 1]])):
            for res in recursiveGridSearchCV(params_full, index_of_param + 1, deepcopy(params_current), i):
                yield res

def gridSearchCV(params_full):
    keys = sorted(list(params_full.keys()))
    ret = []
    for i in range(len(params_full[keys[0]])):
        for res in recursiveGridSearchCV(params_full, index_of_choice=i):
            yield res

# %%
def CrossValidate(train_file, test_file, target_column, n_iter, n_classes):
    l = Lock
    params = {
            "population_size": [30, 50, 100, 500],
            "mutation_prob": [0.05, 0.3],
            "elitism": [0, 1, 5],
            "max_levels": [4], # três níveis gera até 16 nós.
            "min_levels": [1],
            "crossover_prob": [0.6 ,0.9],
            "k": [3, 7],
            "generations": [30, 50, 100, 500],
    }
    results = []
    it = 0
    for param in gridSearchCV(params):
        print("parameters: ")
        print(dumps(param, indent=4))
        result = evaluate("data/glass_train.csv", 
                          "data/glass_test.csv", 
                          "glass_type", 
                          {**param, "classes": n_classes, "checkpoint_prefix": str(it) + "_"}, 
                          n_iter)
        results.append({
            "result": result,
            "params": param 
        })

    return results

# %%
results_glass = CrossValidate("data/glass_train.csv", "data/glass_test.csv", "glass_type", 10, 7)
# Out:
# parameters:
# {
#     "crossover_prob": 0.6,
#     "elitism": 0,
#     "generations": 30,
#     "k": 3,
#     "max_levels": 4,
#     "min_levels": 1,
#     "mutation_prob": 0.05,
#     "population_size": 30
# }
# Generation 1 out of 30
# |████████████████████| avg: 0.02967 - max: 0.20408 - min: 0.00000
# Generation 2 out of 30
# |████████████████████| avg: 0.06842 - max: 0.25324 - min: 0.00000
# Generation 3 out of 30
# |████████████████████| avg: 0.09862 - max: 0.20408 - min: 0.00000
# Generation 4 out of 30
# |████████████████████| avg: 0.10566 - max: 0.20408 - min: 0.00000
# Generation 5 out of 30
# |████████████████████| avg: 0.10238 - max: 0.20408 - min: 0.00000
# Generation 6 out of 30
# |████████████████████| avg: 0.10161 - max: 0.22267 - min: 0.00000
# Saving checkpoint at checkpoints/checkpoint_1.json
# Generation 7 out of 30
# |████████████████████| avg: 0.11596 - max: 0.22267 - min: 0.00000
# Generation 8 out of 30
# |████████████████████| avg: 0.11644 - max: 0.26054 - min: 0.00000
# Generation 9 out of 30
# |████████████████████| avg: 0.08273 - max: 0.26054 - min: 0.00000
# Generation 10 out of 30
# |████████████████████| avg: 0.14352 - max: 0.32544 - min: 0.00000
# Generation 11 out of 30
# |████████████████████| avg: 0.16890 - max: 0.32544 - min: 0.00000
# Saving checkpoint at checkpoints/checkpoint_2.json
# Generation 12 out of 30
# |████████████████████| avg: 0.18296 - max: 0.32544 - min: 0.00000
# Generation 13 out of 30
# |████████████████████| avg: 0.21774 - max: 0.32635 - min: 0.00000
# Generation 14 out of 30
# |████████████████████| avg: 0.22330 - max: 0.32635 - min: 0.00000
# Generation 15 out of 30
# |████████████████████| avg: 0.26002 - max: 0.32635 - min: 0.00000
# Generation 16 out of 30
# |████████████████████| avg: 0.25226 - max: 0.34945 - min: 0.00000
# Saving checkpoint at checkpoints/checkpoint_3.json
# Generation 17 out of 30
# |████████████████████| avg: 0.27631 - max: 0.34945 - min: 0.00000
# Generation 18 out of 30
# |████████████████████| avg: 0.29312 - max: 0.34945 - min: 0.18949
# Generation 19 out of 30
# |████████████████████| avg: 0.29076 - max: 0.34945 - min: 0.18949
# Generation 20 out of 30
# |████████████████████| avg: 0.25668 - max: 0.34945 - min: 0.02000
# Generation 21 out of 30
# |████████████████████| avg: 0.26422 - max: 0.34945 - min: 0.18949
# Saving checkpoint at checkpoints/checkpoint_4.json
# Generation 22 out of 30
# |████████████████████| avg: 0.28209 - max: 0.34945 - min: 0.03185
# Generation 23 out of 30
# |████████████████████| avg: 0.26384 - max: 0.34945 - min: 0.00000
# Generation 24 out of 30
# |████████████████████| avg: 0.25927 - max: 0.34945 - min: 0.18949
# Generation 25 out of 30
# |████████████████████| avg: 0.29099 - max: 0.34945 - min: 0.18949
# Generation 26 out of 30
# |████████████████████| avg: 0.28918 - max: 0.34945 - min: 0.18949
# Saving checkpoint at checkpoints/checkpoint_5.json
# Generation 27 out of 30
# |████████████████████| avg: 0.27134 - max: 0.34945 - min: 0.18949
# Generation 28 out of 30
# |████████████████████| avg: 0.28689 - max: 0.34945 - min: 0.18949
# Generation 29 out of 30
# |████████████████████| avg: 0.26256 - max: 0.34945 - min: 0.18949
# Generation 30 out of 30
# |████████████████████| avg: 0.29046 - max: 0.34945 - min: 0.18949
# Generation 1 out of 30
# |████████████████████| avg: 0.03731 - max: 0.20408 - min: 0.00000
# Generation 2 out of 30
# |████████████████████| avg: 0.09846 - max: 0.26700 - min: 0.00000
# Generation 3 out of 30
# |████████████████████| avg: 0.11300 - max: 0.26700 - min: 0.00000
# Generation 4 out of 30
# |████████████████████| avg: 0.13692 - max: 0.26700 - min: 0.00000
# Generation 5 out of 30
# |████████████████████| avg: 0.15054 - max: 0.26700 - min: 0.00000
# Generation 6 out of 30
# |████████████████████| avg: 0.13269 - max: 0.26700 - min: 0.00000
# Saving checkpoint at checkpoints/checkpoint_1.json
# Generation 7 out of 30
# |████████████████████| avg: 0.13727 - max: 0.26700 - min: 0.00000
# Generation 8 out of 30
# |████████████████████| avg: 0.18454 - max: 0.26700 - min: 0.00000
# Generation 9 out of 30
# |████████████████████| avg: 0.14553 - max: 0.26700 - min: 0.00000
# Generation 10 out of 30
# |████████████████████| avg: 0.11056 - max: 0.26700 - min: 0.00000
# Generation 11 out of 30
# |████████████████████| avg: 0.13038 - max: 0.26700 - min: 0.00000
# Saving checkpoint at checkpoints/checkpoint_2.json
# Generation 12 out of 30
# |████████████████████| avg: 0.13177 - max: 0.26700 - min: 0.00000
# Generation 13 out of 30
# |████████████████████| avg: 0.10836 - max: 0.26700 - min: 0.00000
# Generation 14 out of 30
# |████████████████████| avg: 0.13510 - max: 0.26700 - min: 0.00000
# Generation 15 out of 30
# |████████████████████| avg: 0.15550 - max: 0.26700 - min: 0.00000
# Generation 16 out of 30
# |████████████████████| avg: 0.16175 - max: 0.29694 - min: 0.10105
# Saving checkpoint at checkpoints/checkpoint_3.json
# Generation 17 out of 30
# |████████████████████| avg: 0.12234 - max: 0.29694 - min: 0.00000
# Generation 18 out of 30
# |████████████████████| avg: 0.16943 - max: 0.29694 - min: 0.10105
# Generation 19 out of 30
# |████████████████████| avg: 0.18466 - max: 0.29694 - min: 0.00000
# Generation 20 out of 30
# |████████████████████| avg: 0.15047 - max: 0.29694 - min: 0.00000
# Generation 21 out of 30
# |████████████████████| avg: 0.20761 - max: 0.29694 - min: 0.10105
# Saving checkpoint at checkpoints/checkpoint_4.json
# Generation 22 out of 30
# |████████████████████| avg: 0.18864 - max: 0.29694 - min: 0.00000
# Generation 23 out of 30
# |████████████████████| avg: 0.16336 - max: 0.29694 - min: 0.10105
# Generation 24 out of 30
# |████████████████████| avg: 0.19401 - max: 0.29694 - min: 0.10105
# Generation 25 out of 30
# |████████████████████| avg: 0.19353 - max: 0.29694 - min: 0.08964
# Generation 26 out of 30
# |████████████████████| avg: 0.21123 - max: 0.29694 - min: 0.00000
# Saving checkpoint at checkpoints/checkpoint_5.json
# Generation 27 out of 30
# |████████████████████| avg: 0.15329 - max: 0.29694 - min: 0.10105
# Generation 28 out of 30
# |████████████████████| avg: 0.16989 - max: 0.29694 - min: 0.10105
# Generation 29 out of 30
# |██████              | avg: 0.19002 - max: 0.29694 - min: 0.10105
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-0bf4be19b133> in <module>
# ----> 1 results_glass = CrossValidate("data/glass_train.csv", "data/glass_test.csv", "glass_type", 10, 7)
#
# <ipython-input-6-419d7e8ce54b> in CrossValidate(train_file, test_file, target_column, n_iter, n_classes)
#      16         print("parameters: ")
#      17         print(dumps(param, indent=4))
# ---> 18         result = evaluate("data/glass_train.csv",
#      19                           "data/glass_test.csv",
#      20                           "glass_type",
#
# <ipython-input-3-8990febe35bf> in evaluate(train_file, test_file, target_column, params, n_iter)
#      15     fitnesses = []
#      16     for it in range(n_iter):
# ---> 17         train_result = train(params, X_train, Y_train)
#      18         fitness = train_result["model"](X_test, Y_test)
#      19         total_fitness += fitness
#
# <ipython-input-2-5affce7d7ccf> in train(params, X, Y)
#       1 def train(params, X, Y):
#       2     model = StructuredGrammarEvolution(array_len=len(X[0]), **params)
# ----> 3     history = model.fit(X, Y)
#       4     return {"model": model, "history":history}
#
# ~/ufmg/compnat/TP1/sge/sge.py in fit(self, X, Y)
#     119             for i, d in enumerate(self.population):
#     120                 if d["fitness"] == None:
# --> 121                     self.evaluate_individual(d)
#     122                 if d["fitness"] < min_fit:
#     123                     min_fit = d["fitness"]
#
# ~/ufmg/compnat/TP1/sge/sge.py in evaluate_individual(self, ind)
#     100     def evaluate_individual(self, ind):
#     101         try:
# --> 102             score = self._eval(ind, self.X, self.Y)
#     103         except ZeroDivisionError:
#     104             score = 0
#
# ~/ufmg/compnat/TP1/sge/sge.py in _eval(self, ind, X, Y)
#      89             return 0
#      90         # treina o modelo
# ---> 91         kmeans_instance.process()
#      92         # recupera os clusters gerados
#      93         clusters = kmeans_instance.get_clusters()
#
# ~/miniconda3/lib/python3.8/site-packages/pyclustering/cluster/kmeans.py in process(self)
#     370             self.__process_by_ccore()
#     371         else:
# --> 372             self.__process_by_python()
#     373
#     374         return self
#
# ~/miniconda3/lib/python3.8/site-packages/pyclustering/cluster/kmeans.py in __process_by_python(self)
#     409
#     410         while maximum_change > self.__tolerance and iteration < self.__itermax:
# --> 411             self.__clusters = self.__update_clusters()
#     412             updated_centers = self.__update_centers()  # changes should be calculated before assignment
#     413
#
# ~/miniconda3/lib/python3.8/site-packages/pyclustering/cluster/kmeans.py in __update_clusters(self)
#     513         clusters = [[] for _ in range(len(self.__centers))]
#     514
# --> 515         dataset_differences = self.__calculate_dataset_difference(len(clusters))
#     516
#     517         optimum_indexes = numpy.argmin(dataset_differences, axis=0)
#
# ~/miniconda3/lib/python3.8/site-packages/pyclustering/cluster/kmeans.py in __calculate_dataset_difference(self, amount_clusters)
#     567                 dataset_differences[index_center] = self.__metric(self.__pointer_data, self.__centers[index_center])
#     568             else:
# --> 569                 dataset_differences[index_center] = [self.__metric(point, self.__centers[index_center])
#     570                                                      for point in self.__pointer_data]
#     571
#
# ~/miniconda3/lib/python3.8/site-packages/pyclustering/cluster/kmeans.py in <listcomp>(.0)
#     567                 dataset_differences[index_center] = self.__metric(self.__pointer_data, self.__centers[index_center])
#     568             else:
# --> 569                 dataset_differences[index_center] = [self.__metric(point, self.__centers[index_center])
#     570                                                      for point in self.__pointer_data]
#     571
#
# ~/miniconda3/lib/python3.8/site-packages/pyclustering/utils/metric.py in __call__(self, point1, point2)
#     130
#     131         """
# --> 132         return self.__calculator(point1, point2)
#     133
#     134
#
# ~/ufmg/compnat/TP1/sge/tree.py in <lambda>(X1, X2)
#
# KeyboardInterrupt:

# %%
results_breast_cancer = CrossValidate("data/breast_cancer_coimbra_train.csv", "data/breast_cancer_coimbra_test.csv", "Classification", 10, 2)
